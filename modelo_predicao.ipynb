# %% [markdown]
# ### **Modelo de predição - Projeto 3**

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %matplotlib inline

import statsmodels.api as sm
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D

# Para ter melhor print
from IPython.display import display

# %% [markdown]
# ##### **Split em Treino e Teste**

# %%
dados = pd.read_csv("pnad23_filtrado.csv")

# %%
### Função utilitária para fazer a regressão com constante adicionada

def regress(Y,X):
    '''
    Y: coluna do DataFrame utilizada como variável resposta (TARGET)
    X: coluna(s) do DataFrame utilizadas como variável(is) explicativas (FEATURES)
    '''
    X_cp = sm.add_constant(X)
    model = sm.OLS(Y,X_cp)
    results = model.fit()
    
    return results

# %%
dados.isnull().sum()
# Out:
# Estado                 0
# Sexo                   0
# Idade                  0
# Cor_ou_Raça            0
# Escolaridade           0
# Ocupação               0
# Faixa_de_rendimento    0
# Rendimento_Bruto       0
# dtype: int64

# %%
dados.dtypes
# Out:
# Estado                  object
# Sexo                    object
# Idade                    int64
# Cor_ou_Raça             object
# Escolaridade            object
# Ocupação                object
# Faixa_de_rendimento     object
# Rendimento_Bruto       float64
# dtype: object

# %%
x_colunas = dados[['Estado', 'Sexo', 'Idade', 'Cor_ou_Raça', 'Escolaridade', 'Ocupação','Faixa_de_rendimento']]

y_colunas = dados[['Rendimento_Bruto']]

# %%
x_dummies = pd.get_dummies(x_colunas)
x_dummies = x_dummies.astype(int)
x_dummies.dtypes
# Out:
# Idade                                   int32
# Estado_Acre                             int32
# Estado_Alagoas                          int32
# Estado_Amapá                            int32
# Estado_Amazonas                         int32
#                                         ...
# Faixa_de_rendimento_[1SM]+1 a [2SM]     int32
# Faixa_de_rendimento_[20SM]+1 ou mais    int32
# Faixa_de_rendimento_[2SM]+1 a [3SM]     int32
# Faixa_de_rendimento_[3SM]+1 a [5SM]     int32
# Faixa_de_rendimento_[5SM]+1 a [10SM]    int32
# Length: 65, dtype: object

# %%
# Out:
#           Sexo  Idade Cor_ou_Raça  \
# 0        Homem     30       Parda
# 1       Mulher     50       Parda
# 2       Mulher     54      Branca
# 3        Homem     36       Parda
# 4        Homem     33      Branca
# ...        ...    ...         ...
# 175176  Mulher     48      Branca
# 175177  Mulher     28      Branca
# 175178   Homem     38      Branca
# 175179   Homem     51      Branca
# 175180  Mulher     56      Branca
#
#                                        Escolaridade  \
# 0             Regular do ensino médio ou do 2º grau
# 1                              Superior - graduação
# 2                              Superior - graduação
# 3       Regular do ensino fundamental ou do 1º grau
# 4             Regular do ensino médio ou do 2º grau
# ...                                             ...
# 175176                         Superior - graduação
# 175177                         Superior - graduação
# 175178             Especialização de nível superior
# 175179                         Superior - graduação
# 175180                         Superior - graduação
#
#                                                  Ocupação Faixa_de_rendimento  \
# 0                                           Conta Própria     [3SM]+1 a [5SM]
# 1       Empregado do setor público (inclusive empresas...     [2SM]+1 a [3SM]
# 2       Empregado do setor público (inclusive empresas...     [2SM]+1 a [3SM]
# 3                                           Conta Própria     [2SM]+1 a [3SM]
# 4                                           Conta Própria     [2SM]+1 a [3SM]
# ...                                                   ...                 ...
# 175176                         Empregado do setor privado     [3SM]+1 a [5SM]
# 175177  Empregado do setor público (inclusive empresas...     [2SM]+1 a [3SM]
# 175178                         Empregado do setor privado    [5SM]+1 a [10SM]
# 175179                         Empregado do setor privado     [3SM]+1 a [5SM]
# 175180  Empregado do setor público (inclusive empresas...     [3SM]+1 a [5SM]
#
#         Estado_Acre  Estado_Alagoas  Estado_Amapá  Estado_Amazonas  ...  \
# 0             False           False         False            False  ...
# 1             False           False         False            False  ...
# 2             False           False         False            False  ...
# 3             False           False         False            False  ...
# 4             False           False         False            False  ...
# ...             ...             ...           ...              ...  ...
# 175176        False           False         False            False  ...
# 175177        False           False         False            False  ...
# 175178        False           False         False            False  ...
# 175179        False           False         False            False  ...
# 175180        False           False         False            False  ...
#
#         Estado_Piaui  Estado_Rio Grande do Norte  Estado_Rio Grande do Sul  \
# 0              False                       False                     False
# 1              False                       False                     False
# 2              False                       False                     False
# 3              False                       False                     False
# 4              False                       False                     False
# ...              ...                         ...                       ...
# 175176         False                       False                     False
# 175177         False                       False                     False
# 175178         False                       False                     False
# 175179         False                       False                     False
# 175180         False                       False                     False
#
#         Estado_Rio de Janeiro  Estado_Rondônia  Estado_Roraima  \
# 0                       False             True           False
# 1                       False             True           False
# 2                       False             True           False
# 3                       False             True           False
# 4                       False             True           False
# ...                       ...              ...             ...
# 175176                  False            False           False
# 175177                  False            False           False
# 175178                  False            False           False
# 175179                  False            False           False
# 175180                  False            False           False
#
#         Estado_Santa Catarina  Estado_Sergipe  Estado_São Paulo  \
# 0                       False           False             False
# 1                       False           False             False
# 2                       False           False             False
# 3                       False           False             False
# 4                       False           False             False
# ...                       ...             ...               ...
# 175176                  False           False             False
# 175177                  False           False             False
# 175178                  False           False             False
# 175179                  False           False             False
# 175180                  False           False             False
#
#         Estado_Tocantins
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ...                  ...
# 175176             False
# 175177             False
# 175178             False
# 175179             False
# 175180             False
#
# [175181 rows x 33 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_dummies ,y_colunas , test_size=0.33, random_state= 42 )

# %%
x_train = x_train.astype(int)
y_train = y_train.astype(int)
x_train.dtypes
# Out:
# Idade                                   int32
# Estado_Acre                             int32
# Estado_Alagoas                          int32
# Estado_Amapá                            int32
# Estado_Amazonas                         int32
#                                         ...
# Faixa_de_rendimento_[1SM]+1 a [2SM]     int32
# Faixa_de_rendimento_[20SM]+1 ou mais    int32
# Faixa_de_rendimento_[2SM]+1 a [3SM]     int32
# Faixa_de_rendimento_[3SM]+1 a [5SM]     int32
# Faixa_de_rendimento_[5SM]+1 a [10SM]    int32
# Length: 65, dtype: object

# %%
regress(y_train, x_train).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Rendimento_Bruto   R-squared:                       0.808
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     8389.
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):               0.00
# Time:                        18:29:57   Log-Likelihood:            -1.0440e+06
# No. Observations:              117371   AIC:                         2.088e+06
# Df Residuals:                  117311   BIC:                         2.089e+06
# Df Model:                          59
# Covariance Type:            nonrobust
# =================================================================================================================================================================================
#                                                                                                                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                
# Escolaridade_Antigo ginásio (médio 1º ciclo)                                                                    226.1784     83.987      2.693      0.007      61.564     390.793
# Escolaridade_Antigo primário (elementar)                                                                        211.6302     64.508      3.281      0.001      85.196     338.064
# Escolaridade_Classe de alfabetização - CA                                                                       199.4308     82.555      2.416      0.016      37.624     361.238
# Escolaridade_Creche (disponível apenas no questionário anual de educação)                                       335.3509    825.807      0.406      0.685   -1283.218    1953.920
# Escolaridade_Doutorado                                                                                          648.3344    100.694      6.439      0.000     450.975     845.694
# Escolaridade_Educação de jovens e adultos (EJA) ou supletivo do 1º grau                                         232.0710     79.308      2.926      0.003      76.629     387.513
# Escolaridade_Educação de jovens e adultos (EJA) ou supletivo do 2º grau                                         268.8687     69.845      3.849      0.000     131.973     405.764
# Escolaridade_Especialização de nível superior                                                                   467.7838     63.511      7.365      0.000     343.302     592.265
# Escolaridade_Mestrado                                                                                           447.2009     81.254      5.504      0.000     287.945     606.457
# Escolaridade_Pré-escola                                                                                         245.8307    138.040      1.781      0.075     -24.725     516.387
# Escolaridade_Regular do ensino fundamental ou do 1º grau                                                        267.6549     60.140      4.451      0.000     149.782     385.528
# Escolaridade_Regular do ensino médio ou do 2º grau                                                              297.2793     59.977      4.957      0.000     179.726     414.832
# Escolaridade_Superior - graduação                                                                               368.2191     60.691      6.067      0.000     249.265     487.173
# Ocupação_Conta Própria                                                                                          694.2625     17.300     40.131      0.000     660.355     728.170
# Ocupação_Empregado do setor privado                                                                             751.8444     16.489     45.596      0.000     719.526     784.163
# Ocupação_Empregado do setor público (inclusive empresas de economia mista)                                      751.7962     19.875     37.827      0.000     712.842     790.750
# Ocupação_Empregador                                                                                            1087.0782     25.788     42.155      0.000    1036.535    1137.621
# Ocupação_Militar do exército, da marinha, da aeronáutica, da polícia militar ou do corpo de bombeiros militar   819.4028     52.535     15.597      0.000     716.434     922.371
# Ocupação_Trabalhador doméstico                                                                                  702.6723     23.829     29.488      0.000     655.968     749.376
# Faixa_de_rendimento_1 a [0,5SM]                                                                               -8882.4014     22.115   -401.651      0.000   -8925.746   -8839.057
# Faixa_de_rendimento_[0,5SM]+1 a [1SM]                                                                         -8133.9951     18.566   -438.109      0.000   -8170.384   -8097.606
# Faixa_de_rendimento_[10SM]+1 a [20SM]                                                                          8253.6800     39.998    206.354      0.000    8175.285    8332.075
# Faixa_de_rendimento_[1SM]+1 a [2SM]                                                                           -7469.3863     17.159   -435.296      0.000   -7503.018   -7435.754
# Faixa_de_rendimento_[20SM]+1 ou mais                                                                           3.231e+04     76.243    423.822      0.000    3.22e+04    3.25e+04
# Faixa_de_rendimento_[2SM]+1 a [3SM]                                                                           -6275.0206     20.304   -309.047      0.000   -6314.817   -6235.224
# Faixa_de_rendimento_[3SM]+1 a [5SM]                                                                           -4609.5139     20.613   -223.620      0.000   -4649.915   -4569.113
# Faixa_de_rendimento_[5SM]+1 a [10SM]                                                                           -389.7450     25.864    -15.069      0.000    -440.437    -339.053
# ==============================================================================
# Omnibus:                   396870.444   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):     171471164964.830
# Skew:                          61.373   Prob(JB):                         0.00
# Kurtosis:                    5923.078   Cond. No.                     1.82e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.81e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """
