# %%
import pandas as pd

# %% [markdown]
# Leitura da base de dados completa

# %%
#Rodando a base de dados completa do segundo semestre

pnad23_2_all = pd.read_csv('https://www.dropbox.com/scl/fi/kvhduq8ocy2o1yj4l0ycc/pnad23_2.csv?rlkey=ni8nhwkv84xg59mp1cnd4gsto&st=yr8uiq5k&dl=1')
pnad23_2_all
# Out:
#          Ano  Trimestre  UF  Capital  RM_RIDE        UPA  Estrato  V1008  \
# 0       2023          2  11     11.0      NaN  110000016  1110011      1
# 1       2023          2  11     11.0      NaN  110000016  1110011      1
# 2       2023          2  11     11.0      NaN  110000016  1110011      2
# 3       2023          2  11     11.0      NaN  110000016  1110011      3
# 4       2023          2  11     11.0      NaN  110000016  1110011      3
# ...      ...        ...  ..      ...      ...        ...      ...    ...
# 474570  2023          2  53     53.0      NaN  530060880  5310111     13
# 474571  2023          2  53     53.0      NaN  530060880  5310111     13
# 474572  2023          2  53     53.0      NaN  530060880  5310111     14
# 474573  2023          2  53     53.0      NaN  530060880  5310111     14
# 474574  2023          2  53     53.0      NaN  530060880  5310111     14
#
#         V1014  V1016  ...    V1028191    V1028192    V1028193    V1028194  \
# 0          10      3  ...  451.548556  200.231600  239.078436  508.791587
# 1          10      3  ...  451.548556  200.231600  239.078436  508.791587
# 2          10      3  ...  217.964623   98.704681  108.979781  230.958261
# 3          10      3  ...  452.393952  212.449131  229.969963  498.761017
# 4          10      3  ...  452.393952  212.449131  229.969963  498.761017
# ...       ...    ...  ...         ...         ...         ...         ...
# 474570     11      1  ...  393.082569    0.000000    0.000000  416.131491
# 474571     11      1  ...  393.082569    0.000000    0.000000  416.131491
# 474572     11      1  ...  306.219511    0.000000    0.000000  317.890988
# 474573     11      1  ...  306.219511    0.000000    0.000000  317.890988
# 474574     11      1  ...  306.219511    0.000000    0.000000  317.890988
#
#           V1028195    V1028196    V1028197    V1028198  V1028199    V1028200
# 0         0.000000    0.000000  515.061463    0.000000       0.0  225.178143
# 1         0.000000    0.000000  515.061463    0.000000       0.0  225.178143
# 2         0.000000    0.000000  248.378245    0.000000       0.0  111.051514
# 3         0.000000    0.000000  532.511276    0.000000       0.0  229.261311
# 4         0.000000    0.000000  532.511276    0.000000       0.0  229.261311
# ...            ...         ...         ...         ...       ...         ...
# 474570  806.942713  406.701836  399.331903  408.248725       0.0    0.000000
# 474571  806.942713  406.701836  399.331903  408.248725       0.0    0.000000
# 474572  654.353840  322.037855  306.475497  312.130129       0.0    0.000000
# 474573  654.353840  322.037855  306.475497  312.130129       0.0    0.000000
# 474574  654.353840  322.037855  306.475497  312.130129       0.0    0.000000
#
# [474575 rows x 420 columns]

# %%
# Escolhendo as colunas inicialmente escolhidas
# faixa do rendimento, rendimento bruto,

colunas = ['V403311','V403312',]


#Lendo a base de dados apenas com as colunas

pnad23_2_small = pd.read_csv('https://www.dropbox.com/scl/fi/kvhduq8ocy2o1yj4l0ycc/pnad23_2.csv?rlkey=ni8nhwkv84xg59mp1cnd4gsto&st=yr8uiq5k&dl=1', usecols = colunas)
pnad23_2_small
# Out:
#         V403311  V403312
# 0           5.0   5000.0
# 1           NaN      NaN
# 2           4.0   3500.0
# 3           NaN      NaN
# 4           NaN      NaN
# ...         ...      ...
# 474570      6.0  10000.0
# 474571      3.0   2500.0
# 474572      5.0   5000.0
# 474573      5.0   5000.0
# 474574      NaN      NaN
#
# [474575 rows x 2 columns]

# %%
# Renomenando as colunas sem nome

pnad23_2_small.rename(columns= {}, inplace = True)
